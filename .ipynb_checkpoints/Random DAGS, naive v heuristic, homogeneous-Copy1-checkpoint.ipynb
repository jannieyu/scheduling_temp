# %%
import json 
import networkx as nx
  

from conjecture.consolidated_functions import *
from conjecture.all_valid_orderings import *
from conjecture.optimization_functions import *
from iterative_heuristic.modified_etf import Mod_ETF
from iterative_heuristic.consolidated import *
from iterative_heuristic.approximate_speeds import *
from makespan_energy.construct_graph_util import *
from makespan_energy.visualization_util import *
from trace_data.graph_list_from_trace import *
import networkx as nx
import numpy as np
import math
import plotly.express as px
import pandas as pd

# %%
# Construct DAGs

file_list = ['soykb-chameleon-10fastq-10ch-001.json',
'soykb-chameleon-10fastq-20ch-001.json',
'soykb-chameleon-20fastq-10ch-001.json',
'soykb-chameleon-20fastq-20ch-001.json',
'soykb-chameleon-30fastq-10ch-001.json',
'soykb-chameleon-30fastq-20ch-001.json',
'soykb-chameleon-40fastq-10ch-001.json',
'soykb-chameleon-40fastq-20ch-001.json',
'soykb-chameleon-50fastq-10ch-001.json',
'soykb-chameleon-50fastq-20ch-001.json']
    
G_list = []

for file in file_list:
    
    # Opening JSON file 
    f = open('pegasus-traces-master/soykb/chameleon-cloud/' + file) 

    # returns JSON object as  
    # a dictionary 
    data = json.load(f) 

    taskname_to_id = {}
    id_count = 0

    G = nx.DiGraph()

    for task in data['workflow']['jobs']:

        child_id = id_count
        id_count += 1
        taskname_to_id[task['name']] = child_id

        if not G.has_node(child_id):
                G.add_node(child_id)

        for parent in task['parents']:
            if parent in taskname_to_id:

                parent_id = taskname_to_id[parent]

            else:

                parent_id = id_count
                id_count += 1
                taskname_to_id[parent] = parent_id


            if not G.has_edge(parent_id, child_id):
                    G.add_edge(parent_id, child_id)
    print(len(G.nodes))

    
   
    G_list.append(G)
    
    # Closing file 
    f.close()
# Out:
# 96
# 156
# 176
# 286
# 256
# 416
# 336
# 546
# 416
# 676

# %%
G_list[0]

# %%
mrt = True
tie_breaking_rule = 2
plot = False
num = 5
x = []
y = []
lbs= []
ubs = []
 
num_machines = 50
naives = []
heur = []
for num_tasks in [10,50,150]:
    counter = 0
    while counter != 5:
        
        seed=random.randint(0, 100000)
        edges = random.randint(2, num_tasks-1)
        num_machines = random.randint(2, num_tasks-1)
        G = random_dag(num_tasks, edges, seed=seed)
    
    
        w = [1 for _ in range(num_tasks)]
        s = [1 for _ in range(num_tasks)]

        naive, true, order =iterative_and_naive_heuristic_no_ratio(num_machines, w, G, naive_version=2, iterations=1,verbose=False)
        _, _, obj_opt, _ = get_objective_single_ordering(True, G, w, order, plot=plot, compare=False)
        d = get_optimal_schedule(mrt, G, num_machines, w, plot, verbose=False)
        
        # Record data only if solver was successful
        if obj_opt != 10000000 and d["objective_task_scaling"] != 10000000:

            x.append(num_tasks)
            heur.append(true)
            naives.append(naive)
            y.append(obj_opt)
            lbs.append(d["objective_task_scaling"])
            ub = obj_ub_precise = 2 * sum(psize_to_speed(ub_lst_graph(G, order)))
            ubs.append(ub)
            counter += 1
# Out:
# /Users/jannie/scheduling_temp/iterative_heuristic/modified_etf.py:56: RuntimeWarning: divide by zero encountered in double_scalars
#   self.task_process_time = [self.w[i] / self.s[i] for i in range(self.num_tasks)]
# /Users/jannie/scheduling_temp/iterative_heuristic/modified_etf.py:94: RuntimeWarning: invalid value encountered in double_scalars
#   energy += ((self.w[j] * self.power(self.s[j]))/ self.s[j])
# /Users/jannie/scheduling_temp/iterative_heuristic/modified_etf.py:95: RuntimeWarning: invalid value encountered in double_scalars
#   total_cost += (self.t[j][1] + ((self.w[j] * self.power(self.s[j]))/ self.s[j]))
# apm 104.5.118.159_gk_model1 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :           20
#    Constants    :            0
#    Variables    :          252
#    Intermediates:            0
#    Connections  :          200
#    Equations    :          142
#    Residuals    :          142
#
#  Number of state variables:            252
#  Number of total equations: -          161
#  Number of slack variables: -           39
#  ---------------------------------------
#  Degrees of freedom       :             52
#
#  **********************************************
#  Steady State Optimization with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.10, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      602
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       90
#
# Total number of variables............................:      252
#                      variables with only lower bounds:       62
#                 variables with lower and upper bounds:       80
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      161
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e+01 5.00e+00 1.33e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.7587446e+01 2.45e-01 2.03e+01  -0.8 3.54e+01    -  4.52e-02 9.71e-01f  1
#    2  3.6406484e+01 1.71e-01 1.41e+01  -1.9 4.83e+00    -  5.67e-01 3.09e-01h  1
#    3  3.5042023e+01 1.05e-01 1.12e+01  -0.2 9.81e+00    -  2.45e-01 1.00e+00f  1
#    4  3.5108794e+01 8.20e-05 7.58e+00  -1.6 7.58e-02   2.0 9.95e-01 1.00e+00h  1
#    5  3.1833797e+01 1.60e-04 6.83e+00  -7.6 3.08e+01    -  2.97e-01 9.63e-02f  1
#    6  2.9814834e+01 2.13e-03 4.67e+00  -3.1 3.19e+00    -  8.18e-01 3.20e-01f  1
#    7  2.7497478e+01 2.64e-02 9.64e-01  -3.2 3.60e+00    -  8.92e-01 8.46e-01f  1
#    8  2.3759778e+01 4.06e-01 1.00e+00  -4.0 6.38e+00    -  8.21e-01 1.00e+00f  1
#    9  2.5319267e+01 2.92e-02 2.05e-01  -4.4 1.36e+00    -  8.86e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.5408521e+01 2.16e-03 1.34e-02  -6.3 1.55e-01    -  9.66e-01 1.00e+00h  1
#   11  2.5413413e+01 3.25e-05 2.00e-04 -11.0 7.65e-03    -  9.87e-01 9.90e-01h  1
#   12  2.5413484e+01 2.49e-09 1.49e-08 -11.0 6.42e-03    -  9.99e-01 1.00e+00h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.5413484429637819e+01    2.5413484429637819e+01
# Dual infeasibility......:   1.4929489003124954e-08    1.4929489003124954e-08
# Constraint violation....:   2.4876241067062210e-09    2.4876241067062210e-09
# Complementarity.........:   3.5792826343134599e-11    3.5792826343134599e-11
# Overall NLP error.......:   1.4929489003124954e-08    1.4929489003124954e-08
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 12
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.016
# Total CPU secs in NLP function evaluations           =      0.009
#
# EXIT: Optimal Solution Found.
#
#  The solution was found.
#
#  The final value of the objective function is    25.4134844296378
#
#  ---------------------------------------------------
#  Solver         :  IPOPT (v3.12)
#  Solution time  :   3.120000002672896E-002 sec
#  Objective      :    25.4134844296378
#  Successful solution
#  ---------------------------------------------------
#
# Results
# 0 Speed: [1.4142135624] Ending Time: [1.2844570304] Interval: [0.57735, 1.28446] Task process time: 0.70711
# 1 Speed: [0.99999999627] Ending Time: [2.2844570217] Interval: [1.28446, 2.28446] Task process time: 1.0
# 2 Speed: [1.4142135624] Ending Time: [0.7071067712] Interval: [0.0, 0.70711] Task process time: 0.70711
# 3 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 4 Speed: [1.4142135624] Ending Time: [1.2844570304] Interval: [0.57735, 1.28446] Task process time: 0.70711
# 5 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 6 Speed: [1.7320508076] Ending Time: [0.5773502592] Interval: [0.0, 0.57735] Task process time: 0.57735
# 7 Speed: [1.7320508076] Ending Time: [0.5773502592] Interval: [0.0, 0.57735] Task process time: 0.57735
# 8 Speed: [0.99999999627] Ending Time: [2.2844570217] Interval: [1.28446, 2.28446] Task process time: 1.0
# 9 Speed: [0.99999999999] Ending Time: [1.7071067612] Interval: [0.70711, 1.70711] Task process time: 1.0
# Objective: 25.41348443
# apm 104.5.118.159_gk_model3 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :           21
#    Constants    :            0
#    Variables    :          274
#    Intermediates:            0
#    Connections  :          221
#    Equations    :          153
#    Residuals    :          153
#
#  Number of state variables:            274
#  Number of total equations: -          173
#  Number of slack variables: -           40
#  ---------------------------------------
#  Degrees of freedom       :             61
#
#  **********************************************
#  Steady State Optimization with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.10, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      656
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      100
#
# Total number of variables............................:      274
#                      variables with only lower bounds:       63
#                 variables with lower and upper bounds:       90
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      173
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e+01 5.00e+00 1.34e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.6958763e+01 2.79e-01 1.93e+01  -0.8 3.57e+01    -  4.64e-02 9.46e-01f  1
#    2  3.6125910e+01 2.13e-01 1.47e+01  -1.9 4.53e+00    -  4.58e-01 2.39e-01h  1
#    3  3.5841149e+01 1.79e-01 1.23e+01  -6.6 4.04e+00    -  2.56e-01 1.60e-01h  1
#    4  3.4604808e+01 1.08e-01 7.42e+00  -2.6 5.83e+00    -  2.86e-01 3.98e-01h  1
#    5  2.8488132e+01 1.02e-01 2.23e+00  -1.7 8.91e+00    -  5.22e-01 1.00e+00f  1
#    6  2.7843993e+01 1.40e-01 1.75e+00  -1.2 2.41e+01    -  6.95e-01 4.37e-02f  1
#    7  2.7590727e+01 1.34e-01 1.60e+00  -7.1 1.10e+01    -  5.18e-01 4.12e-02f  1
#    8  2.2365058e+01 5.04e+01 4.70e+03  -2.0 1.12e+01    -  7.11e-01 8.88e-01f  1
#    9  3.4055873e+01 1.82e+01 2.32e+03  -1.8 9.99e+00    -  1.11e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.2496189e+01 2.64e+00 8.96e+02  -1.8 8.53e+00    -  7.53e-01 1.00e+00h  1
#   11  3.4976367e+01 3.37e+00 3.95e+02  -1.8 7.75e+00    -  5.21e-01 1.00e+00f  1
#   12  3.1191822e+01 2.43e+00 1.76e+02  -1.8 3.45e+01    -  4.18e-01 1.00e+00h  1
#   13  2.9058937e+01 1.52e+00 7.76e+01  -1.8 4.18e+01    -  4.93e-01 1.00e+00h  1
#   14  2.7567553e+01 1.01e+00 3.40e+01  -1.8 8.73e+01    -  9.23e-01 1.00e+00h  1
#   15  2.6596569e+01 6.41e-01 1.52e+01  -3.0 6.93e+01    -  7.16e-01 9.40e-01h  1
#   16  2.6078614e+01 3.98e-01 6.29e+00  -4.1 2.49e+01    -  9.87e-01 1.00e+00h  1
#   17  2.5890325e+01 2.13e-01 2.36e+00  -5.4 7.52e+01    -  7.90e-01 1.00e+00h  1
#   18  2.5886908e+01 8.50e-02 6.99e-01  -6.6 2.52e+01    -  9.88e-01 1.00e+00h  1
#   19  2.5932921e+01 1.73e-02 1.16e-01  -8.2 4.40e+01    -  8.99e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  2.5948636e+01 7.48e-04 4.57e-03  -9.2 4.74e+01    -  9.89e-01 1.00e+00h  1
#   21  2.5949382e+01 1.30e-06 7.82e-06 -11.0 6.53e+01    -  9.06e-01 1.00e+00h  1
#   22  2.5949383e+01 3.82e-12 8.84e-10 -11.0 6.87e+02    -  9.44e-01 1.00e+00h  1
#
# Number of Iterations....: 22
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.5949382809472503e+01    2.5949382809472503e+01
# Dual infeasibility......:   8.8359275451921349e-10    8.8359275451921349e-10
# Constraint violation....:   3.8206104946425512e-12    3.8206104946425512e-12
# Complementarity.........:   1.4583257574105061e-10    1.4583257574105061e-10
# Overall NLP error.......:   8.8359275451921349e-10    8.8359275451921349e-10
#
#
# Number of objective function evaluations             = 23
# Number of objective gradient evaluations             = 23
# Number of equality constraint evaluations            = 23
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 23
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 22
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.022
# Total CPU secs in NLP function evaluations           =      0.018
#
# EXIT: Optimal Solution Found.
#
#  The solution was found.
#
#  The final value of the objective function is    25.9493828094725
#
#  ---------------------------------------------------
#  Solver         :  IPOPT (v3.12)
#  Solution time  :   5.029999997350387E-002 sec
#  Objective      :    25.9493828094725
#  Successful solution
#  ---------------------------------------------------
# Results
# 0 Speed: [1.4142135624] Ending Time: [0.70710677117] Interval: [0.0, 0.70711] Task process time: 0.70711
# 1 Speed: [1.0] Ending Time: [0.99999999] Interval: [0.0, 1.0] Task process time: 1.0
# 2 Speed: [1.9999999999] Ending Time: [0.49999999002] Interval: [0.0, 0.5] Task process time: 0.5
# 3 Speed: [1.7320508075] Ending Time: [1.0773502492] Interval: [0.5, 1.07735] Task process time: 0.57735
# 4 Speed: [1.0] Ending Time: [2.7844570105] Interval: [1.78446, 2.78446] Task process time: 1.0
# 5 Speed: [1.4142135624] Ending Time: [0.7071067712] Interval: [0.0, 0.70711] Task process time: 0.70711
# 6 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 7 Speed: [1.0] Ending Time: [1.7071067612] Interval: [0.70711, 1.70711] Task process time: 1.0
# 8 Speed: [1.0000000001] Ending Time: [1.7071067611] Interval: [0.70711, 1.70711] Task process time: 1.0
# 9 Speed: [1.4142135623] Ending Time: [1.7844570204] Interval: [1.07735, 1.78446] Task process time: 0.70711
# Objective: 25.949382809
# apm 104.5.118.159_gk_model5 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :           21
#    Constants    :            0
#    Variables    :          268
#    Intermediates:            0
#    Connections  :          221
#    Equations    :          147
#    Residuals    :          147
#
#  Number of state variables:            268
#  Number of total equations: -          167
#  Number of slack variables: -           34
#  ---------------------------------------
#  Degrees of freedom       :             67
#
#  **********************************************
#  Steady State Optimization with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.10, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      632
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      100
#
# Total number of variables............................:      268
#                      variables with only lower bounds:       57
#                 variables with lower and upper bounds:       90
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      167
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e+01 5.00e+00 1.37e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.5844841e+01 2.11e-01 2.29e+01  -0.8 3.36e+01    -  4.02e-02 9.70e-01f  1
#    2  3.4425985e+01 1.46e-01 1.57e+01  -1.4 5.53e+00    -  6.61e-01 3.14e-01f  1
#    3  2.9257792e+01 3.62e-02 1.43e+00  -1.9 7.32e+00    -  5.20e-01 1.00e+00f  1
#    4  1.7056558e+01 4.58e+01 4.04e+03  -1.4 2.73e+01    -  6.54e-01 5.86e-01f  1
#    5  2.0398233e+01 3.94e+01 3.50e+03  -1.3 2.24e+01    -  1.20e-01 1.54e-01h  1
#    6  4.3695654e+01 1.44e+01 1.73e+03  -1.3 2.35e+01    -  1.24e-01 1.00e+00h  1
#    7  6.4951421e+01 1.69e+00 6.24e+02  -1.3 1.99e+01    -  6.02e-01 1.00e+00h  1
#    8  4.5210088e+01 2.76e+00 2.73e+02  -1.3 2.00e+01    -  7.70e-01 1.00e+00f  1
#    9  3.5275958e+01 2.08e+00 1.23e+02  -1.3 2.04e+01    -  4.34e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.0400760e+01 1.22e+00 5.36e+01  -1.3 2.04e+01    -  5.70e-01 1.00e+00f  1
#   11  2.6648250e+01 8.38e-01 2.33e+01  -1.3 5.25e+01    -  8.39e-01 1.00e+00f  1
#   12  2.4333091e+01 5.20e-01 1.05e+01  -2.3 3.62e+01    -  7.47e-01 9.14e-01f  1
#   13  2.3169099e+01 3.14e-01 4.19e+00  -3.2 1.66e+01    -  9.76e-01 1.00e+00h  1
#   14  2.2893340e+01 1.51e-01 1.46e+00  -4.4 4.78e+01    -  7.88e-01 1.00e+00h  1
#   15  2.2996596e+01 4.82e-02 3.58e-01  -5.5 1.53e+01    -  9.82e-01 1.00e+00h  1
#   16  2.3103750e+01 5.82e-03 3.70e-02  -7.2 1.85e+01    -  9.36e-01 1.00e+00h  1
#   17  2.3120541e+01 1.38e-04 8.53e-04 -11.0 4.78e-02    -  9.81e-01 9.90e-01h  1
#   18  2.3120956e+01 4.54e-08 2.72e-07 -11.0 2.42e+00    -  9.98e-01 1.00e+00h  1
#
# Number of Iterations....: 18
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.3120955588519692e+01    2.3120955588519692e+01
# Dual infeasibility......:   2.7239675758779504e-07    2.7239675758779504e-07
# Constraint violation....:   4.5403485198623196e-08    4.5403485198623196e-08
# Complementarity.........:   5.0044265508185740e-10    5.0044265508185740e-10
# Overall NLP error.......:   2.7239675758779504e-07    2.7239675758779504e-07
#
#
# Number of objective function evaluations             = 19
# Number of objective gradient evaluations             = 19
# Number of equality constraint evaluations            = 19
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 19
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 18
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.018
# Total CPU secs in NLP function evaluations           =      0.014
#
# EXIT: Optimal Solution Found.
#
#  The solution was found.
#
#  The final value of the objective function is    23.1209555885197
#
#  ---------------------------------------------------
#  Solver         :  IPOPT (v3.12)
#  Solution time  :   4.019999998854473E-002 sec
#  Objective      :    23.1209555885197
#  Successful solution
#  ---------------------------------------------------
#
# Results
# 0 Speed: [1.0] Ending Time: [1.7071067612] Interval: [0.70711, 1.70711] Task process time: 1.0
# 1 Speed: [1.0] Ending Time: [1.5773502492] Interval: [0.57735, 1.57735] Task process time: 1.0
# 2 Speed: [0.99999993189] Ending Time: [1.0000000127] Interval: [0.0, 1.0] Task process time: 1.0
# 3 Speed: [1.4142135623] Ending Time: [0.70710677121] Interval: [0.0, 0.70711] Task process time: 0.70711
# 4 Speed: [0.99999993189] Ending Time: [1.0000000127] Interval: [0.0, 1.0] Task process time: 1.0
# 5 Speed: [1.7320508076] Ending Time: [0.57735025919] Interval: [0.0, 0.57735] Task process time: 0.57735
# 6 Speed: [1.4142135624] Ending Time: [0.7071067712] Interval: [0.0, 0.70711] Task process time: 0.70711
# 7 Speed: [1.0] Ending Time: [1.7071067612] Interval: [0.70711, 1.70711] Task process time: 1.0
# 8 Speed: [1.0] Ending Time: [1.5773502492] Interval: [0.57735, 1.57735] Task process time: 1.0
# 9 Speed: [0.99999993189] Ending Time: [1.0000000127] Interval: [0.0, 1.0] Task process time: 1.0
# Objective: 23.120955589
# apm 104.5.118.159_gk_model7 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :           14
#    Constants    :            0
#    Variables    :          116
#    Intermediates:            0
#    Connections  :           74
#    Equations    :           72
#    Residuals    :           72
#
#  Number of state variables:            116
#  Number of total equations: -           85
#  Number of slack variables: -           29
#  ---------------------------------------
#  Degrees of freedom       :              2
#
#  **********************************************
#  Steady State Optimization with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.10, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      262
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       30
#
# Total number of variables............................:      116
#                      variables with only lower bounds:       52
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       85
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e+01 5.00e+00 1.33e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.7996101e+01 6.02e-01 1.04e+02   0.1 4.64e+01    -  1.59e-02 1.00e+00f  1
#    2  4.8807520e+01 7.65e-02 1.16e+01  -6.0 6.07e+00    -  6.17e-01 8.77e-01f  1
#    3  2.9194993e+01 2.34e-01 1.37e+00  -1.1 2.09e+01    -  6.46e-01 1.00e+00f  1
#    4  2.1682126e+01 4.35e+01 3.57e+03  -0.8 1.46e+01    -  7.01e-01 8.84e-01f  1
#    5  3.2409331e+01 1.84e+01 1.78e+03  -0.9 9.52e+00    -  2.31e-01 1.00e+00h  1
#    6  5.4264658e+01 1.87e+00 6.56e+02  -0.9 2.16e+01    -  5.65e-01 1.00e+00h  1
#    7  4.1497140e+01 2.64e+00 2.84e+02  -0.9 1.29e+01    -  6.42e-01 1.00e+00f  1
#    8  3.4447752e+01 2.10e+00 1.28e+02  -0.9 3.22e+01    -  4.05e-01 1.00e+00f  1
#    9  3.0889646e+01 1.30e+00 5.61e+01  -0.9 4.66e+01    -  6.13e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.8449228e+01 8.49e-01 2.44e+01  -0.9 1.21e+02    -  6.42e-01 1.00e+00f  1
#   11  2.5503481e+01 5.41e-01 1.01e+01  -1.5 8.16e+01    -  8.06e-01 1.00e+00f  1
#   12  2.4663775e+01 3.16e-01 4.24e+00  -2.9 1.67e+01    -  9.69e-01 9.43e-01h  1
#   13  2.4463684e+01 1.55e-01 1.48e+00  -3.8 7.20e+01    -  9.06e-01 1.00e+00h  1
#   14  2.4532168e+01 4.96e-02 3.68e-01  -5.3 2.39e+01    -  9.67e-01 1.00e+00h  1
#   15  2.4605031e+01 6.12e-03 3.89e-02  -6.8 2.42e+01    -  9.66e-01 1.00e+00h  1
#   16  2.4616783e+01 1.50e-04 9.27e-04 -11.0 4.40e-02    -  9.81e-01 9.90e-01h  1
#   17  2.4617084e+01 5.37e-08 3.22e-07 -11.0 2.15e+00    -  9.98e-01 1.00e+00h  1
#
# Number of Iterations....: 17
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.4617083792878354e+01    2.4617083792878354e+01
# Dual infeasibility......:   3.2225493931720334e-07    3.2225493931720334e-07
# Constraint violation....:   5.3726179347156402e-08    5.3726179347156402e-08
# Complementarity.........:   1.0520118865166162e-09    1.0520118865166162e-09
# Overall NLP error.......:   3.2225493931720334e-07    3.2225493931720334e-07
#
#
# Number of objective function evaluations             = 18
# Number of objective gradient evaluations             = 18
# Number of equality constraint evaluations            = 18
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 18
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 17
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.014
# Total CPU secs in NLP function evaluations           =      0.006
#
# EXIT: Optimal Solution Found.
#
#  The solution was found.
#
#  The final value of the objective function is    24.6170837928784
#
#  ---------------------------------------------------
#  Solver         :  IPOPT (v3.12)
#  Solution time  :   2.660000001196750E-002 sec
#  Objective      :    24.6170837928784
#  Successful solution
#  ---------------------------------------------------
# Results
# 0 Speed: [1.0] Ending Time: [2.2844570204] Interval: [1.28446, 2.28446] Task process time: 1.0
# 1 Speed: [1.0] Ending Time: [1.632455512] Interval: [0.63246, 1.63246] Task process time: 1.0
# 2 Speed: [1.0] Ending Time: [1.6324555121] Interval: [0.63246, 1.63246] Task process time: 1.0
# 3 Speed: [0.99999991942] Ending Time: [1.0000000169] Interval: [0.0, 1.0] Task process time: 1.0
# 4 Speed: [0.99999991942] Ending Time: [1.0000000169] Interval: [0.0, 1.0] Task process time: 1.0
# 5 Speed: [1.4142135624] Ending Time: [1.2844570304] Interval: [0.57735, 1.28446] Task process time: 0.70711
# 6 Speed: [1.7320508076] Ending Time: [0.5773502592] Interval: [0.0, 0.57735] Task process time: 0.57735
# 7 Speed: [1.5811388301] Ending Time: [0.63245552204] Interval: [0.0, 0.63246] Task process time: 0.63246
# 8 Speed: [1.0] Ending Time: [1.632455512] Interval: [0.63246, 1.63246] Task process time: 1.0
# 9 Speed: [1.5811388301] Ending Time: [0.63245552204] Interval: [0.0, 0.63246] Task process time: 0.63246
# Objective: 24.617083793
# apm 104.5.118.159_gk_model9 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :           21
#    Constants    :            0
#    Variables    :          269
#    Intermediates:            0
#    Connections  :          221
#    Equations    :          148
#    Residuals    :          148
#
#  Number of state variables:            269
#  Number of total equations: -          168
#  Number of slack variables: -           35
#  ---------------------------------------
#  Degrees of freedom       :             66
#
#  **********************************************
#  Steady State Optimization with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.10, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      636
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      100
#
# Total number of variables............................:      269
#                      variables with only lower bounds:       58
#                 variables with lower and upper bounds:       90
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      168
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e+01 5.00e+00 1.24e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.6771311e+01 2.55e-01 1.72e+01  -0.8 3.37e+01    -  5.45e-02 1.00e+00f  1
#    2  3.4725364e+01 1.54e-01 1.03e+01  -1.9 6.34e+00    -  5.91e-01 4.02e-01f  1
#    3  3.1169031e+01 1.13e-01 6.37e+00  -0.3 9.61e+00    -  3.11e-01 1.00e+00f  1
#    4  3.0082801e+01 2.27e-03 7.04e-01  -1.8 7.04e-01   0.0 9.58e-01 1.00e+00h  1
#    5  2.0560722e+01 3.72e+00 2.93e+01  -2.2 4.11e+01    -  6.14e-01 2.58e-01f  1
#    6  2.2561158e+01 1.52e+00 1.50e+01  -2.3 1.68e+00    -  7.73e-01 7.96e-01h  1
#    7  2.3318053e+01 5.11e-01 6.61e+00  -3.7 5.93e-01    -  9.30e-01 9.24e-01h  1
#    8  2.3256860e+01 2.23e-01 2.49e+00  -5.1 2.87e-01    -  7.49e-01 1.00e+00h  1
#    9  2.3249018e+01 9.03e-02 7.53e-01  -5.5 3.52e-01    -  9.81e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.3295391e+01 1.93e-02 1.31e-01  -6.8 4.84e-01    -  9.04e-01 1.00e+00h  1
#   11  2.3312771e+01 9.40e-04 5.76e-03  -8.2 1.73e-01    -  9.83e-01 1.00e+00h  1
#   12  2.3313703e+01 5.85e-06 3.56e-05 -11.0 1.56e-02    -  9.90e-01 9.96e-01h  1
#   13  2.3313708e+01 7.93e-11 4.93e-10 -11.0 1.61e+00    -  8.10e-01 1.00e+00h  1
#
# Number of Iterations....: 13
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.3313708359015454e+01    2.3313708359015454e+01
# Dual infeasibility......:   4.9257428245455096e-10    4.9257428245455096e-10
# Constraint violation....:   7.9302786559765082e-11    7.9302786559765082e-11
# Complementarity.........:   8.3080768570544716e-11    8.3080768570544716e-11
# Overall NLP error.......:   4.9257428245455096e-10    4.9257428245455096e-10
#
#
# Number of objective function evaluations             = 14
# Number of objective gradient evaluations             = 14
# Number of equality constraint evaluations            = 14
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 14
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 13
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.016
# Total CPU secs in NLP function evaluations           =      0.010
#
# EXIT: Optimal Solution Found.
#
#  The solution was found.
#
#  The final value of the objective function is    23.3137083590155
#
#  ---------------------------------------------------
#  Solver         :  IPOPT (v3.12)
#  Solution time  :   3.390000000945292E-002 sec
#  Objective      :    23.3137083590155
#  Successful solution
#  ---------------------------------------------------
#
# Results
# 0 Speed: [1.4142135624] Ending Time: [1.4142135424] Interval: [0.70711, 1.41421] Task process time: 0.70711
# 1 Speed: [1.4142135624] Ending Time: [0.70710677119] Interval: [0.0, 0.70711] Task process time: 0.70711
# 2 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 3 Speed: [1.4142135624] Ending Time: [0.70710677119] Interval: [0.0, 0.70711] Task process time: 0.70711
# 4 Speed: [0.99999999988] Ending Time: [2.4142135324] Interval: [1.41421, 2.41421] Task process time: 1.0
# 5 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 6 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 7 Speed: [1.0] Ending Time: [1.7071067612] Interval: [0.70711, 1.70711] Task process time: 1.0
# 8 Speed: [1.4142135624] Ending Time: [0.7071067712] Interval: [0.0, 0.70711] Task process time: 0.70711
# 9 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# Objective: 23.313708359
# apm 104.5.118.159_gk_model11 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :           84
#    Constants    :            0
#    Variables    :         3732
#    Intermediates:            0
#    Connections  :         3384
#    Equations    :         1998
#    Residuals    :         1998
#
#  Number of state variables:           3732
#  Number of total equations: -         2081
#  Number of slack variables: -          295
#  ---------------------------------------
#  Degrees of freedom       :           1356
#
#  **********************************************
#  Steady State Optimization with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.10, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:     9386
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1650
#
# Total number of variables............................:     3732
#                      variables with only lower bounds:      398
#                 variables with lower and upper bounds:     1600
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2081
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e+01 5.00e+00 1.66e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.9608200e+02 3.88e-01 3.36e+01  -0.5 1.75e+02    -  2.86e-02 1.00e+00f  1
#    2  1.9399398e+02 3.29e-01 2.84e+01  -2.0 1.88e+01    -  5.25e-01 1.53e-01h  1
#    3  1.9284584e+02 2.29e-01 1.98e+01  -1.2 1.89e+01    -  4.67e-01 3.04e-01f  1
#    4  1.9093270e+02 1.74e-01 1.50e+01  -2.5 2.16e+01    -  3.65e-01 2.42e-01h  1
#    5  1.8863474e+02 1.28e-01 1.10e+01  -3.1 2.36e+01    -  3.55e-01 2.65e-01h  1
#    6  1.8318390e+02 7.89e-02 6.76e+00  -7.2 2.96e+01    -  2.25e-01 3.87e-01f  1
#    7  1.6311059e+02 1.17e-01 3.99e+00  -1.5 3.79e+01    -  6.15e-01 1.00e+00f  1
#    8  1.6327956e+02 4.40e-02 2.45e+00  -2.0 4.43e-01   0.0 9.86e-01 6.30e-01h  1
#    9  1.5029631e+02 4.21e-01 1.47e+00  -2.1 3.77e+01    -  9.37e-01 6.92e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.5448789e+02 1.02e-01 4.86e-01  -3.2 6.65e+00    -  9.53e-01 7.86e-01h  1
#   11  1.5564018e+02 9.28e-03 6.68e-02  -9.0 1.33e+00    -  9.18e-01 9.67e-01h  1
#   12  1.5569082e+02 3.44e-04 2.29e-03 -10.1 3.48e-02    -  9.75e-01 9.88e-01h  1
#   13  1.5569169e+02 1.11e-06 7.21e-06 -11.0 6.32e-04    -  9.97e-01 9.98e-01h  1
#   14  1.5569169e+02 3.19e-12 1.77e-08 -11.0 3.18e-03    -  9.65e-01 1.00e+00h  1
#
# Number of Iterations....: 14
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5569169385942865e+02    1.5569169385942865e+02
# Dual infeasibility......:   1.7656560657997034e-08    1.7656560657997034e-08
# Constraint violation....:   3.1894487051431497e-12    3.1894487051431497e-12
# Complementarity.........:   7.5857734963835391e-10    7.5857734963835391e-10
# Overall NLP error.......:   1.7656560657997034e-08    1.7656560657997034e-08
#
#
# Number of objective function evaluations             = 15
# Number of objective gradient evaluations             = 15
# Number of equality constraint evaluations            = 15
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 15
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 14
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.120
# Total CPU secs in NLP function evaluations           =      0.189
#
# EXIT: Optimal Solution Found.
#
#  The solution was found.
#
#  The final value of the objective function is    155.691693859429
#
#  ---------------------------------------------------
#  Solver         :  IPOPT (v3.12)
#  Solution time  :   0.334700000006706      sec
#  Objective      :    155.691693859429
#  Successful solution
#  ---------------------------------------------------
#
# Results
# 0 Speed: [0.9999999999] Ending Time: [4.9166613369] Interval: [3.91666, 4.91666] Task process time: 1.0
# 1 Speed: [2.5116537594] Ending Time: [0.39814404002] Interval: [0.0, 0.39814] Task process time: 0.39814
# 2 Speed: [3.6529218823] Ending Time: [0.2737534488] Interval: [0.0, 0.27375] Task process time: 0.27375
# 3 Speed: [1.0] Ending Time: [2.5392790348] Interval: [1.53928, 2.53928] Task process time: 1.0
# 4 Speed: [1.4142135624] Ending Time: [1.5392790448] Interval: [0.83217, 1.53928] Task process time: 0.70711
# 5 Speed: [1.0] Ending Time: [3.1322043163] Interval: [2.1322, 3.1322] Task process time: 1.0
# 6 Speed: [1.316805709] Ending Time: [2.1322043263] Interval: [1.37279, 2.1322] Task process time: 0.75941
# 7 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 8 Speed: [1.4142135624] Ending Time: [2.116629304] Interval: [1.40952, 2.11663] Task process time: 0.70711
# 9 Speed: [2.3039975275] Ending Time: [0.83217227357] Interval: [0.39814, 0.83217] Task process time: 0.43403
# 10 Speed: [1.2869194696] Ending Time: [2.1322043263] Interval: [1.35515, 2.1322] Task process time: 0.77705
# 11 Speed: [2.2360679775] Ending Time: [0.4472135855] Interval: [0.0, 0.44721] Task process time: 0.44721
# 12 Speed: [2.1470586864] Ending Time: [2.1322043263] Interval: [1.66645, 2.1322] Task process time: 0.46575
# 13 Speed: [2.368514514] Ending Time: [1.6664508819] Interval: [1.24425, 1.66645] Task process time: 0.42221
# 14 Speed: [2.5709649945] Ending Time: [1.2442453305] Interval: [0.85529, 1.24425] Task process time: 0.38896
# 15 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 16 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 17 Speed: [1.0] Ending Time: [2.3551549276] Interval: [1.35515, 2.35515] Task process time: 1.0
# 18 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 19 Speed: [1.0] Ending Time: [0.99999998999] Interval: [0.0, 1.0] Task process time: 1.0
# 20 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 21 Speed: [1.7320508075] Ending Time: [3.2095545756] Interval: [2.6322, 3.20955] Task process time: 0.57735
# 22 Speed: [1.0] Ending Time: [1.3805904491] Interval: [0.38059, 1.38059] Task process time: 1.0
# 23 Speed: [1.4142135623] Ending Time: [3.9166613468] Interval: [3.20955, 3.91666] Task process time: 0.70711
# 24 Speed: [1.0] Ending Time: [0.99999998999] Interval: [0.0, 1.0] Task process time: 1.0
# 25 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 26 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 27 Speed: [1.2016742444] Ending Time: [0.83217227355] Interval: [0.0, 0.83217] Task process time: 0.83217
# 28 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 29 Speed: [1.0] Ending Time: [1.7071067612] Interval: [0.70711, 1.70711] Task process time: 1.0
# 30 Speed: [1.0] Ending Time: [3.116629294] Interval: [2.11663, 3.11663] Task process time: 1.0
# 31 Speed: [3.5133798938] Ending Time: [0.55837964781] Interval: [0.27375, 0.55838] Task process time: 0.28463
# 32 Speed: [1.9121092336] Ending Time: [1.3551549376] Interval: [0.83217, 1.35515] Task process time: 0.52298
# 33 Speed: [1.7320508076] Ending Time: [1.5245638347] Interval: [0.94721, 1.52456] Task process time: 0.57735
# 34 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 35 Speed: [1.7320508075] Ending Time: [1.4095225328] Interval: [0.83217, 1.40952] Task process time: 0.57735
# 36 Speed: [3.3680615015] Ending Time: [0.85528633015] Interval: [0.55838, 0.85529] Task process time: 0.29691
# 37 Speed: [1.0] Ending Time: [3.2316705959] Interval: [2.23167, 3.23167] Task process time: 1.0
# 38 Speed: [1.0] Ending Time: [0.99999999001] Interval: [0.0, 1.0] Task process time: 1.0
# 39 Speed: [1.0] Ending Time: [0.99999999] Interval: [0.0, 1.0] Task process time: 1.0
# 40 Speed: [1.9323501948] Ending Time: [1.3727908608] Interval: [0.85529, 1.37279] Task process time: 0.5175
# 41 Speed: [1.4142135624] Ending Time: [0.70710677119] Interval: [0.0, 0.70711] Task process time: 0.70711
# 42 Speed: [1.0] Ending Time: [2.3727908508] Interval: [1.37279, 2.37279] Task process time: 1.0
# 43 Speed: [2.2144381059] Ending Time: [0.83217227357] Interval: [0.38059, 0.83217] Task process time: 0.45158
# 44 Speed: [1.4142135624] Ending Time: [0.70710677119] Interval: [0.0, 0.70711] Task process time: 0.70711
# 45 Speed: [2.6274961703] Ending Time: [0.3805904591] Interval: [0.0, 0.38059] Task process time: 0.38059
# 46 Speed: [1.9999999999] Ending Time: [2.6322043164] Interval: [2.1322, 2.6322] Task process time: 0.5
# 47 Speed: [2.0] Ending Time: [0.94721357551] Interval: [0.44721, 0.94721] Task process time: 0.5
# 48 Speed: [1.4142135624] Ending Time: [2.2316706059] Interval: [1.52456, 2.23167] Task process time: 0.70711
# 49 Speed: [1.0] Ending Time: [1.7071067612] Interval: [0.70711, 1.70711] Task process time: 1.0
# Objective: 155.69169386
# apm 104.5.118.159_gk_model13 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :          100
#    Constants    :            0
#    Variables    :         5207
#    Intermediates:            0
#    Connections  :         5000
#    Equations    :         2657
#    Residuals    :         2657

# %%
# naives = [572.8281617409056, 1331.3128540244006, 2051.988186148974, 4908.957570715966, 4427.097315671543, 10722.551392522024, 7706.784325022744, 18780.723094156718, 11887.994968277473, 29080.41842969494, 16967.104097800042, 41618.012251501, 22950.791107151243, 56400.18395313568, 29836.001750405976, 73423.87928867387, 37619.11087992854, 92685.47311048009, 46306.79788927975, 114191.64481211497, 55896.00853253448, 137939.34014765336]
# heurs = [351.14748449053826, 698.6688417479015, 1181.833119651485, 2392.931559303018, 2515.1051913091133, 5128.200522698374, 4320.182955770601, 8876.07384841392, 6602.766119158128, 13562.092685406415, 9411.33279943706, 19356.644767630198, 12670.852536835615, 26103.094518568214, 16404.64052815484, 33831.316526414616, 20688.501817054886, 42685.15172746671, 25668.437288627654, 52905.78716201741, 30587.45634664135, 63200.60308232752]
# y = [300.05921, 586.18851, 10000000, 1637.77108, 1520.32995, 10000000, 2333.07674, 10000000, 3254.04157, 6424.66253, 4271.75539, 10000000, 5377.87606, 10000000, 6565.71298, 12977.19203, 7829.99982, 10000000, 9169.60916, 10000000, 10571.28621, 20904.74224]
ratios1 = [n/h for n,h in zip(naives, heur)]
print(ratios1)
ratios2 = [h/true for h, true in zip(heur, y)]
print(ratios2)
ratios3 = [n/true for n, true in zip(naives, y)]
print(ratios3)

# %%
import matplotlib.pyplot as plt
import math

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
 

# plt.scatter(x, y, s=5, label='opt/lb', color='b')
plt.scatter(x, ratios1, label='Naive/Heur', color='k', alpha = 0.5)
# plt.scatter(x, ratios2, label='Heur/Optimal', color='r', alpha = 0.5)
# plt.scatter(x, ratios3, label='Naive/Optimal', color='b', alpha = 0.5)
#plt.scatter(x, naives, label='Naives', color='g')
plt.xlabel('Number of tasks')
plt.ylabel('Ratios')
plt.legend()
plt.show()
